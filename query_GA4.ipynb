# %%
from ga4 import GA4Metadata, GA4Report

# %%
q_meta = GA4Metadata(property_id="357316354")

# %%
metadata = q_meta.return_df()

# %%
metadata.loc[metadata.Type == "Metric"].head(20)
# Out:
#        Type                             API_Name  \
# 193  Metric                      active1DayUsers
# 194  Metric                     active28DayUsers
# 195  Metric                      active7DayUsers
# 196  Metric                          activeUsers
# 197  Metric                           addToCarts
# 198  Metric                       adUnitExposure
# 199  Metric                   advertiserAdClicks
# 200  Metric                     advertiserAdCost
# 201  Metric             advertiserAdCostPerClick
# 202  Metric        advertiserAdCostPerConversion
# 203  Metric              advertiserAdImpressions
# 204  Metric               averagePurchaseRevenue
# 205  Metric  averagePurchaseRevenuePerPayingUser
# 206  Metric        averagePurchaseRevenuePerUser
# 207  Metric                averageRevenuePerUser
# 208  Metric               averageSessionDuration
# 209  Metric                           bounceRate
# 210  Metric                       cartToViewRate
# ...

# %%
q_report = GA4Report(property_id="357316354")

# %%
q_report.return_df(dimensions=['dateHour', 'customEvent:cv_link'], metrics=['activeUsers', 'newUsers', 'bounceRate'])
# Out:
#       dateHour                   customEvent:cv_link  activeUsers  newUsers  \
# 0   2023031018                             (not set)          2.0       2.0
# 1   2023031220                             (not set)          2.0       0.0
# 2   2023031712                                                2.0       1.0
# 3   2023031020                             (not set)          1.0       0.0
# 4   2023031110                             (not set)          1.0       0.0
# 5   2023031123                             (not set)          1.0       0.0
# 6   2023031218                             (not set)          1.0       1.0
# 7   2023031219                             (not set)          1.0       1.0
# 8   2023031220  https://julienolivier3.github.io/cv/          1.0       0.0
# 9   2023031311                             (not set)          1.0       1.0
# 10  2023031318                             (not set)          1.0       1.0
# ...
